# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **Daily Dataset**

# %%
df1= pd.read_csv("/content/daily_cleaned.csv")

# %%
df1
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-04-12       13162       8.500000         8.500000
# 1    1503960366   2016-04-13       10735       6.970000         6.970000
# 2    1503960366   2016-04-14       10460       6.740000         6.740000
# 3    1503960366   2016-04-15        9762       6.280000         6.280000
# 4    1503960366   2016-04-16       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391   2016-05-08       10686       8.110000         8.110000
# 936  8877689391   2016-05-09       20226      18.250000        18.250000
# 937  8877689391   2016-05-10       10733       8.150000         8.150000
# 938  8877689391   2016-05-11       21420      19.559999        19.559999
# 939  8877689391   2016-05-12        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                1.88                      0.55
# 1                         0.0                1.57                      0.69
# 2                         0.0                2.44                      0.40
# 3                         0.0                2.14                      1.26
# 4                         0.0                2.71                      0.41
# ..                        ...                 ...                       ...
# 935                       0.0                1.08                      0.20
# 936                       0.0               11.10                      0.80
# 937                       0.0                1.35                      0.46
# 938                       0.0               13.22                      0.41
# 939                       0.0                1.82                      0.04
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   6.06                     0.00                 25
# 1                   4.71                     0.00                 21
# 2                   3.91                     0.00                 30
# 3                   2.83                     0.00                 29
# 4                   5.04                     0.00                 36
# ..                   ...                      ...                ...
# 935                 6.80                     0.00                 17
# 936                 6.24                     0.05                 73
# 937                 6.28                     0.00                 18
# 938                 5.89                     0.00                 88
# 939                 4.25                     0.00                 23
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     13                   328               728      1985
# 1                     19                   217               776      1797
# 2                     11                   181              1218      1776
# 3                     34                   209               726      1745
# 4                     10                   221               773      1863
# ..                   ...                   ...               ...       ...
# 935                    4                   245              1174      2847
# 936                   19                   217              1131      3710
# 937                   11                   224              1187      2832
# 938                   12                   213              1127      3832
# 939                    1                   137               770      1849
#
# [940 rows x 15 columns]

# %% [markdown]
# # **Visualization**

# %%
top_10_df1 = df1.sort_values(by='TotalSteps', ascending=False).head(10)
# Bar Chart for TotalSteps per Day
plt.figure(figsize=(10, 6))
plt.bar(top_10_df1['ActivityDate'], top_10_df1['TotalSteps'])
plt.title('TotalSteps per Day')
plt.xlabel('ActivityDate')
plt.ylabel('TotalSteps')
plt.show()

# %%
# Grouping by ActivityDate and summing up TotalSteps and TotalDistance
grouped_df1 = df1.groupby('ActivityDate').agg({'TotalSteps': 'sum', 'TotalDistance': 'sum'}).reset_index()
# Plotting the Line Chart
plt.figure(figsize=(12, 6))
plt.plot(grouped_df1['ActivityDate'], grouped_df1['TotalSteps'], label='Total Steps', marker='o')
plt.plot(grouped_df1['ActivityDate'], grouped_df1['TotalDistance'], label='Total Distance', marker='o')
plt.xlabel('ActivityDate')
plt.ylabel('Steps Count')
plt.title('Total Steps vs Total Distance over Time')
plt.legend()
plt.xticks(rotation=90, ha='left')
plt.show()

# %%
# Sorting the DataFrame by TotalSteps in descending order and selecting the top 5 rows
top_5_df1 = df1.sort_values(by='TotalSteps', ascending=False).head(5)

# Creating subplots for each metric
fig, axes = plt.subplots(3, 3, figsize=(15, 12))

# Bar Chart for TotalSteps
axes[0, 0].bar(top_5_df1['ActivityDate'], top_5_df1['TotalSteps'])
axes[0, 0].set_title('TotalSteps')

# Bar Chart for VeryActiveMinutes
axes[0, 1].bar(top_5_df1['ActivityDate'], top_5_df1['VeryActiveMinutes'])
axes[0, 1].set_title('VeryActiveMinutes')

# Bar Chart for TotalDistance
axes[0, 2].bar(top_5_df1['ActivityDate'], top_5_df1['TotalDistance'])
axes[0, 2].set_title('TotalDistance')

# Bar Chart for SedentaryMinutes
axes[1, 0].bar(top_5_df1['ActivityDate'], top_5_df1['SedentaryMinutes'])
axes[1, 0].set_title('SedentaryMinutes')

# Bar Chart for FairlyActiveMinutes
axes[1, 1].bar(top_5_df1['ActivityDate'], top_5_df1['FairlyActiveMinutes'])
axes[1, 1].set_title('FairlyActiveMinutes')

# Bar Chart for LightlyActiveMinutes
axes[1, 2].bar(top_5_df1['ActivityDate'], top_5_df1['LightlyActiveMinutes'])
axes[1, 2].set_title('LightlyActiveMinutes')

# Bar Chart for VeryActiveDistance
axes[2, 0].bar(top_5_df1['ActivityDate'], top_5_df1['VeryActiveDistance'])
axes[2, 0].set_title('VeryActiveDistance')

# Bar Chart for ModeratelyActiveDistance
axes[2, 1].bar(top_5_df1['ActivityDate'], top_5_df1['ModeratelyActiveDistance'])
axes[2, 1].set_title('ModeratelyActiveDistance')

# Bar Chart for LightActiveDistance
axes[2, 2].bar(top_5_df1['ActivityDate'], top_5_df1['LightActiveDistance'])
axes[2, 2].set_title('LightActiveDistance')

# Adjusting layout for better readability
plt.tight_layout()
plt.show()

# %%
top_10_df1 = df1.sort_values(by='TotalDistance', ascending=False).head(10)
# Bar Chart for TotalDistance per DATE
plt.figure(figsize=(10, 5))
plt.bar(top_10_df1['ActivityDate'], top_10_df1['TotalDistance'])
plt.title('TotalDisance per Date')
plt.xlabel('ActivityDate')
plt.ylabel('TotalDistance')
plt.show()

# %% [markdown]
# # **Weight_Info_Dataset**

# %%
df2= pd.read_csv("/content/weight_log_info_data_cleaned.csv")

# %%
df2
# Out:
#             Id Date Weight        BMI    WeightKg  WeightPounds
# 0   1503960366  02-05-2016  22.650000   52.599998    115.963146
# 1   1503960366  03-05-2016  22.650000   52.599998    115.963146
# 2   1927972279  13-04-2016  47.540001  133.500000    294.317120
# 3   2873212765  21-04-2016  21.450001   56.700001    125.002104
# 4   2873212765  12-05-2016  21.690001   57.299999    126.324875
# ..         ...         ...        ...         ...           ...
# 62  8877689391  06-05-2016  25.440001   85.000000    187.392923
# 63  8877689391  08-05-2016  25.559999   85.400002    188.274775
# 64  8877689391  09-05-2016  25.610001   85.500000    188.495234
# 65  8877689391  11-05-2016  25.559999   85.400002    188.274775
# 66  8877689391  12-05-2016  25.139999   84.000000    185.188300
#
# [67 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df2['Id'].plot(kind='hist', bins=20, title='Id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df2['BMI'].plot(kind='hist', bins=20, title='BMI')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df2['WeightKg'].plot(kind='hist', bins=20, title='WeightKg')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df2['WeightPounds'].plot(kind='hist', bins=20, title='WeightPounds')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df2.plot(kind='scatter', x='Id', y='BMI', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df2.plot(kind='scatter', x='BMI', y='WeightKg', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df2.plot(kind='scatter', x='WeightKg', y='WeightPounds', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Id']
#   ys = series['BMI']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df2.sort_values('Id', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Id')
# _ = plt.ylabel('BMI')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Id']
#   ys = series['WeightKg']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df2.sort_values('Id', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Id')
# _ = plt.ylabel('WeightKg')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Id']
#   ys = series['WeightPounds']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df2.sort_values('Id', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Id')
# _ = plt.ylabel('WeightPounds')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Id']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Id'}, axis=1)
#               .sort_values('Id', ascending=True))
#   xs = counted['Id']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df2.sort_values('Id', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Id')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df2['Id'].plot(kind='line', figsize=(8, 4), title='Id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df2['BMI'].plot(kind='line', figsize=(8, 4), title='BMI')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df2['WeightKg'].plot(kind='line', figsize=(8, 4), title='WeightKg')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df2['WeightPounds'].plot(kind='line', figsize=(8, 4), title='WeightPounds')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df2['BMI'].plot(kind='line', figsize=(8, 4), title='BMI')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df2['WeightKg'].plot(kind='line', figsize=(8, 4), title='WeightKg')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ## **Hourly Dataset**

# %%
df3= pd.read_csv("/content/hourly_cleaned.csv")

# %%
df3
# Out:
#                Id ActivityDay ActivityHour  TotalIntensity  AverageIntensity  \
# 0      1503960366  12-04-2016        00:00              20          0.333333
# 1      1503960366  12-04-2016        01:00               8          0.133333
# 2      1503960366  12-04-2016        02:00               7          0.116667
# 3      1503960366  12-04-2016        03:00               0          0.000000
# 4      1503960366  12-04-2016        04:00               0          0.000000
# ...           ...         ...          ...             ...               ...
# 22094  8877689391  12-05-2016        10:00              12          0.200000
# 22095  8877689391  12-05-2016        11:00              29          0.483333
# 22096  8877689391  12-05-2016        12:00              93          1.550000
# 22097  8877689391  12-05-2016        13:00               6          0.100000
# 22098  8877689391  12-05-2016        14:00               9          0.150000
#
#        StepTotal  Calories
# 0            373        81
# 1            160        61
# 2            151        59
# 3              0        47
# 4              0        48
# ...          ...       ...
# 22094        514       126
# 22095       1407       192
# 22096       3135       321
# 22097        307       101
# 22098        457       113
#
# [22099 rows x 7 columns]

# %%
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Id']
  ys = series['Calories']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df3.sort_values('Id', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Id')
_ = plt.ylabel('Calories')

# %%
plt.figure(figsize=(6, 3))
sns.barplot(x='StepTotal', y='Calories', data=df3 )
plt.title('Total Steps And Calories')
plt.xlabel('StepTotal')
plt.ylabel('Calories')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='ActivityHour', y='StepTotal', data=df3 )
plt.title('Total Steps for Each Hour of the Day')
plt.xlabel('ActivityHour')
plt.ylabel('Total Steps')
plt.show()

# %% [markdown]
# ## **Minute Dataset**

# %%
df4= pd.read_csv("/content/minute_merged_cleaned.csv")

# %%
df4
# Out:
#                  Id ActivityDay ActivityMinute  METs  Calories  Intensity  \
# 0        1503960366  12-04-2016       00:00:00    10    0.7865          0
# 1        1503960366  12-04-2016       00:01:00    10    0.7865          0
# 2        1503960366  12-04-2016       00:02:00    10    0.7865          0
# 3        1503960366  12-04-2016       00:03:00    10    0.7865          0
# 4        1503960366  12-04-2016       00:04:00    10    0.7865          0
# ...             ...         ...            ...   ...       ...        ...
# 1048570  7086361926  17-04-2016       19:10:00    10    1.1317          0
# 1048571  7086361926  17-04-2016       19:11:00    10    1.1317          0
# 1048572  7086361926  17-04-2016       19:12:00    10    1.1317          0
# 1048573  7086361926  17-04-2016       19:13:00    10    1.1317          0
# 1048574  7086361926  17-04-2016       19:14:00    10    1.1317          0
#
#          Sleep  Steps
# 0          3.0      0
# 1          2.0      0
# 2          1.0      0
# 3          1.0      0
# 4          1.0      0
# ...        ...    ...
# 1048570    NaN      0
# 1048571    NaN      0
# 1048572    NaN      0
# 1048573    NaN      0
# 1048574    NaN      0
#
# [1048575 rows x 8 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df4['Id'].plot(kind='hist', bins=20, title='Id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df4['METs'].plot(kind='hist', bins=20, title='METs')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df4['Calories'].plot(kind='hist', bins=20, title='Calories')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df4['Intensity'].plot(kind='hist', bins=20, title='Intensity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df4.plot(kind='scatter', x='Id', y='METs', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df4.plot(kind='scatter', x='METs', y='Calories', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df4.plot(kind='scatter', x='Calories', y='Intensity', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df4.plot(kind='scatter', x='Intensity', y='Sleep', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Id']
#   ys = series['METs']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df4.sort_values('Id', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Id')
# _ = plt.ylabel('METs')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Id']
#   ys = series['Calories']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df4.sort_values('Id', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Id')
# _ = plt.ylabel('Calories')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Id']
#   ys = series['Intensity']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df4.sort_values('Id', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Id')
# _ = plt.ylabel('Intensity')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Id']
#   ys = series['Sleep']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df4.sort_values('Id', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Id')
# _ = plt.ylabel('Sleep')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df4['Id'].plot(kind='line', figsize=(8, 4), title='Id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df4['METs'].plot(kind='line', figsize=(8, 4), title='METs')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df4['Calories'].plot(kind='line', figsize=(8, 4), title='Calories')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df4['Intensity'].plot(kind='line', figsize=(8, 4), title='Intensity')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Id']
  ys = series['METs']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(5, 5), layout='constrained')
df_sorted = df4.sort_values('Id', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Id')
_ = plt.ylabel('METs')

# %%
# Selecting relevant columns for the pair plot
columns_for_pair_plot = ['Steps', 'Calories', 'Intensity']

# Pair Plot
sns.pairplot(df4[columns_for_pair_plot])
plt.suptitle('Pair Plot: Steps, Calories, and Intensity', y=1.02)
plt.show()

# %% [markdown]
# ## **HeartRate Dataset**

# %%
df5= pd.read_csv("/content/heart_rate_cleaned.csv")

# %%
df5
# Out:
#                 Id         Day   Time  Heartrate  DailyMeanHeartrate
# 0       2022484408  2016-04-12  07:21        102           74.051532
# 1       2022484408  2016-04-12  07:22         92           74.051532
# 2       2022484408  2016-04-12  07:23         58           74.051532
# 3       2022484408  2016-04-12  07:24         58           74.051532
# 4       2022484408  2016-04-12  07:25         57           74.051532
# ...            ...         ...    ...        ...                 ...
# 333415  8877689391  2016-05-12  14:40         56           69.924843
# 333416  8877689391  2016-05-12  14:41         57           69.924843
# 333417  8877689391  2016-05-12  14:42         56           69.924843
# 333418  8877689391  2016-05-12  14:43         57           69.924843
# 333419  8877689391  2016-05-12  14:44         55           69.924843
#
# [333420 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df5['Id'].plot(kind='hist', bins=20, title='Id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df5['Heartrate'].plot(kind='hist', bins=20, title='Heartrate')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df5['DailyMeanHeartrate'].plot(kind='hist', bins=20, title='DailyMeanHeartrate')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df5.plot(kind='scatter', x='Id', y='Heartrate', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df5.plot(kind='scatter', x='Heartrate', y='DailyMeanHeartrate', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Id']
#   ys = series['Heartrate']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df5.sort_values('Id', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Id')
# _ = plt.ylabel('Heartrate')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Id']
#   ys = series['DailyMeanHeartrate']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df5.sort_values('Id', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Id')
# _ = plt.ylabel('DailyMeanHeartrate')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Id']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Id'}, axis=1)
#               .sort_values('Id', ascending=True))
#   xs = counted['Id']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df5.sort_values('Id', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Id')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Time']
#   ys = series['Heartrate']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df5.sort_values('Time', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Time')
# _ = plt.ylabel('Heartrate')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df5['Id'].plot(kind='line', figsize=(8, 4), title='Id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df5['Heartrate'].plot(kind='line', figsize=(8, 4), title='Heartrate')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df5['DailyMeanHeartrate'].plot(kind='line', figsize=(8, 4), title='DailyMeanHeartrate')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
plt.figure(figsize=(10, 6))
plt.hist(df5['Heartrate'].dropna(), bins=20, color='red', edgecolor='black')
plt.title('Distribution of Heart Rate Measurements')
plt.xlabel('Heartrate')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df5['DailyMeanHeartrate'].dropna(), bins=20, color='green', edgecolor='black')
plt.title(' DailyMeanHeartrate Measurements')
plt.xlabel('DailyMeanHeartrate')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='-', alpha=0.7)
plt.show()

# %% [markdown]
# ## **SleepDay DataSet**

# %%
df6= pd.read_csv("/content/sleep_day_data_cleaned.csv")

# %%
df6
# Out:
#              Id    SleepDay  TotalMinutesAsleep  TotalSleepRecords  \
# 0    1503960366  2016-04-12                 327                  1
# 1    1503960366  2016-04-13                 384                  2
# 2    1503960366  2016-04-15                 412                  1
# 3    1503960366  2016-04-16                 340                  2
# 4    1503960366  2016-04-17                 700                  1
# ..          ...         ...                 ...                ...
# 405  8792009665  2016-04-30                 343                  1
# 406  8792009665  2016-05-01                 503                  1
# 407  8792009665  2016-05-02                 415                  1
# 408  8792009665  2016-05-03                 516                  1
# 409  8792009665  2016-05-04                 439                  1
#
#      TotalTimeInBed
# 0               346
# 1               407
# 2               442
# 3               367
# 4               712
# ..              ...
# 405             360
# 406             527
# 407             423
# 408             545
# 409             463
#
# [410 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df6['Id'].plot(kind='hist', bins=20, title='Id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df6['TotalMinutesAsleep'].plot(kind='hist', bins=20, title='TotalMinutesAsleep')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df6['TotalSleepRecords'].plot(kind='hist', bins=20, title='TotalSleepRecords')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df6['TotalTimeInBed'].plot(kind='hist', bins=20, title='TotalTimeInBed')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df6.plot(kind='scatter', x='Id', y='TotalMinutesAsleep', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df6.plot(kind='scatter', x='TotalMinutesAsleep', y='TotalSleepRecords', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df6.plot(kind='scatter', x='TotalSleepRecords', y='TotalTimeInBed', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Id']
#   ys = series['TotalMinutesAsleep']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df6.sort_values('Id', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Id')
# _ = plt.ylabel('TotalMinutesAsleep')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Id']
#   ys = series['TotalSleepRecords']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df6.sort_values('Id', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Id')
# _ = plt.ylabel('TotalSleepRecords')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Id']
#   ys = series['TotalTimeInBed']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df6.sort_values('Id', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Id')
# _ = plt.ylabel('TotalTimeInBed')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Id']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Id'}, axis=1)
#               .sort_values('Id', ascending=True))
#   xs = counted['Id']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df6.sort_values('Id', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Id')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df6['Id'].plot(kind='line', figsize=(8, 4), title='Id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df6['TotalMinutesAsleep'].plot(kind='line', figsize=(8, 4), title='TotalMinutesAsleep')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df6['TotalSleepRecords'].plot(kind='line', figsize=(8, 4), title='TotalSleepRecords')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df6['TotalTimeInBed'].plot(kind='line', figsize=(8, 4), title='TotalTimeInBed')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
plt.figure(figsize=(10, 6))
plt.hist(df6['TotalMinutesAsleep'].dropna(), bins=20, color='orange', edgecolor='black')
plt.title('TotalMinutesAsleep')
plt.xlabel('TotalMinutesAsleep')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='-', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='TotalSleepRecords', y='TotalMinutesAsleep', data=df6, marker='x', linestyle='--')
sns.lineplot(x='TotalSleepRecords', y='TotalTimeInBed', data=df6, marker='x', linestyle='-')
plt.title('Total Minutes Asleep vs. Total Time In Bed Over Time')
plt.xlabel('TotalSleepRecords')
plt.ylabel('Minutes')
plt.legend(['Total Minutes Asleep', 'Total Time In Bed'])
plt.show()
